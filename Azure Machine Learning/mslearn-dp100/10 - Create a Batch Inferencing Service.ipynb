# %% [markdown]
# # Create a Batch Inferencing Service
#
# Imagine a health clinic takes patient measurements all day, saving the details for each patient in a separate file. Then overnight, the diabetes prediction model can be used to process all of the day's patient data as a batch, generating predictions that will be waiting the following morning so that the clinic can follow up with patients who are predicted to be at risk of diabetes. With Azure Machine Learning, you can accomplish this by creating a *batch inferencing pipeline*; and that's what you'll implement in this exercise.

# %% [markdown]
# ## Connect to your workspace
#
# To get started, connect to your workspace.
#
# > **Note**: If you haven't already established an authenticated session with your Azure subscription, you'll be prompted to authenticate by clicking a link, entering an authentication code, and signing into Azure.

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()
print(auth_header)
# Out:
# {'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6ImpTMVhvMU9XRGpfNTJ2YndHTmd2UU8yVnpNYyIsImtpZCI6ImpTMVhvMU9XRGpfNTJ2YndHTmd2UU8yVnpNYyJ9.....dT6sNZ6uAk5Am3BnWzj1zmcz5LSlqb4K-jO8lSyXMu2anNDVeOmUgNSkKxuhfvBKIogA9IrEPJczOsOU85R6JDe2_YpwPuva6SSqxaSbQxD73d_0JL-rDCSGoG63LcEdbBcN8tB1tmjr6gcyZTZgCbinWwa0mPfgUon1uwsjWJYmM1o3s62azmy5v5RGC0rzLJYILrpLamZxnGhru4k812fs1YBWSZoS6klV1j5d0lLXP_AtA5gAnrBaUPpN90yHJ_it4VpPk6-pK8NCt2wkWXdwnPIkBzfggdVyOZnyS3ME9U0CsetfYcrO01MSeuiHynbhjHvNvjpWauMqWGJB4g'}

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.40.0 to work with lsmltraining

# %% [markdown]
# ## Train and register a model
#
# Now let's train and register a model to deploy in a batch inferencing pipeline.

# %%
from azureml.core import Experiment
from azureml.core import Model
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# Create an Azure ML experiment in your workspace
experiment = Experiment(workspace=ws, name='mslearn-train-diabetes')
run = experiment.start_logging()
print("Starting experiment:", experiment.name)

# load the diabetes dataset
print("Loading Data...")
diabetes = pd.read_csv('data/diabetes.csv')

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train a decision tree model
print('Training a decision tree model')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# Save the trained model
model_file = 'diabetes_model.pkl'
joblib.dump(value=model, filename=model_file)
run.upload_file(name = 'outputs/' + model_file, path_or_stream = './' + model_file)

# Complete the run
run.complete()

# Register the model
run.register_model(model_path='outputs/diabetes_model.pkl', model_name='diabetes_model',
                   tags={'Training context':'Inline Training'},
                   properties={'AUC': run.get_metrics()['AUC'], 'Accuracy': run.get_metrics()['Accuracy']})

print('Model trained and registered.')
# Out:
# Starting experiment: mslearn-train-diabetes
# Loading Data...
# Training a decision tree model
# Accuracy: 0.89
# AUC: 0.8773471316980943
# Model trained and registered.

# %% [markdown]
# ## Generate and upload batch data
#
# Since we don't actually have a fully staffed clinic with patients from whom to get new data for this exercise, you'll generate a random sample from our diabetes CSV file, upload that data to a datastore in the Azure Machine Learning workspace, and register a dataset for it.

# %%
from azureml.core import Datastore, Dataset
import pandas as pd
import os

# Set default data store
ws.set_default_datastore('workspaceblobstore')
default_ds = ws.get_default_datastore()

# Enumerate all datastores, indicating which is the default
for ds_name in ws.datastores:
    print(ds_name, "- Default =", ds_name == default_ds.name)

# Load the diabetes data
diabetes = pd.read_csv('data/diabetes2.csv')
# Get a 100-item sample of the feature columns (not the diabetic label)
sample = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].sample(n=100).values

# Create a folder
batch_folder = './batch-data'
os.makedirs(batch_folder, exist_ok=True)
print("Folder created!")

# Save each sample as a separate file
print("Saving files...")
for i in range(100):
    fname = str(i+1) + '.csv'
    sample[i].tofile(os.path.join(batch_folder, fname), sep=",")
print("files saved!")

# Upload the files to the default datastore
print("Uploading files to datastore...")
default_ds = ws.get_default_datastore()
default_ds.upload(src_dir="batch-data", target_path="batch-data", overwrite=True, show_progress=True)

# Register a dataset for the input data
batch_data_set = Dataset.File.from_files(path=(default_ds, 'batch-data/'), validate=False)
try:
    batch_data_set = batch_data_set.register(workspace=ws, 
                                             name='batch-data',
                                             description='batch data',
                                             create_new_version=True)
except Exception as ex:
    print(ex)

print("Done!")
# Out:
# azureml_globaldatasets - Default = False
# workspaceworkingdirectory - Default = False
# workspaceartifactstore - Default = False
# workspacefilestore - Default = False
# workspaceblobstore - Default = True
# Folder created!
# Saving files...
# "Datastore.upload" is deprecated after version 1.0.69. Please use "Dataset.File.upload_directory" to upload your files             from a local directory and create FileDataset in single method call. See Dataset API change notice at https://aka.ms/dataset-deprecation.
# files saved!
# Uploading files to datastore...
# Uploading an estimated of 100 files
# Uploading batch-data/1.csv
# Uploaded batch-data/1.csv, 1 files out of an estimated total of 100
# Uploading batch-data/10.csv
# Uploaded batch-data/10.csv, 2 files out of an estimated total of 100
# Uploading batch-data/100.csv
# Uploaded batch-data/100.csv, 3 files out of an estimated total of 100
# Uploading batch-data/11.csv
# Uploaded batch-data/11.csv, 4 files out of an estimated total of 100
# Uploading batch-data/12.csv
# Uploaded batch-data/12.csv, 5 files out of an estimated total of 100
# Uploading batch-data/13.csv
# Uploaded batch-data/13.csv, 6 files out of an estimated total of 100
# Uploading batch-data/14.csv
# Uploaded batch-data/14.csv, 7 files out of an estimated total of 100
# Uploading batch-data/15.csv
# Uploaded batch-data/15.csv, 8 files out of an estimated total of 100
# Uploading batch-data/16.csv
# Uploaded batch-data/16.csv, 9 files out of an estimated total of 100
# Uploading batch-data/17.csv
# Uploaded batch-data/17.csv, 10 files out of an estimated total of 100
# Uploading batch-data/18.csv
# Uploaded batch-data/18.csv, 11 files out of an estimated total of 100
# Uploading batch-data/19.csv
# Uploaded batch-data/19.csv, 12 files out of an estimated total of 100
# Uploading batch-data/2.csv
# Uploaded batch-data/2.csv, 13 files out of an estimated total of 100
# Uploading batch-data/20.csv
# Uploaded batch-data/20.csv, 14 files out of an estimated total of 100
# Uploading batch-data/21.csv
# Uploaded batch-data/21.csv, 15 files out of an estimated total of 100
# Uploading batch-data/22.csv
# Uploaded batch-data/22.csv, 16 files out of an estimated total of 100
# Uploading batch-data/23.csv
# Uploaded batch-data/23.csv, 17 files out of an estimated total of 100
# Uploading batch-data/24.csv
# Uploaded batch-data/24.csv, 18 files out of an estimated total of 100
# Uploading batch-data/25.csv
# Uploaded batch-data/25.csv, 19 files out of an estimated total of 100
# Uploading batch-data/26.csv
# Uploaded batch-data/26.csv, 20 files out of an estimated total of 100
# Uploading batch-data/27.csv
# Uploaded batch-data/27.csv, 21 files out of an estimated total of 100
# Uploading batch-data/28.csv
# Uploaded batch-data/28.csv, 22 files out of an estimated total of 100
# Uploading batch-data/29.csv
# Uploaded batch-data/29.csv, 23 files out of an estimated total of 100
# Uploading batch-data/3.csv
# Uploaded batch-data/3.csv, 24 files out of an estimated total of 100
# Uploading batch-data/30.csv
# Uploaded batch-data/30.csv, 25 files out of an estimated total of 100
# Uploading batch-data/31.csv
# Uploaded batch-data/31.csv, 26 files out of an estimated total of 100
# Uploading batch-data/32.csv
# Uploaded batch-data/32.csv, 27 files out of an estimated total of 100
# Uploading batch-data/33.csv
# Uploaded batch-data/33.csv, 28 files out of an estimated total of 100
# Uploading batch-data/34.csv
# Uploaded batch-data/34.csv, 29 files out of an estimated total of 100
# Uploading batch-data/35.csv
# Uploaded batch-data/35.csv, 30 files out of an estimated total of 100
# Uploading batch-data/36.csv
# Uploaded batch-data/36.csv, 31 files out of an estimated total of 100
# Uploading batch-data/37.csv
# Uploaded batch-data/37.csv, 32 files out of an estimated total of 100
# Uploading batch-data/38.csv
# Uploaded batch-data/38.csv, 33 files out of an estimated total of 100
# Uploading batch-data/39.csv
# Uploaded batch-data/39.csv, 34 files out of an estimated total of 100
# Uploading batch-data/4.csv
# Uploaded batch-data/4.csv, 35 files out of an estimated total of 100
# Uploading batch-data/40.csv
# Uploaded batch-data/40.csv, 36 files out of an estimated total of 100
# Uploading batch-data/41.csv
# Uploaded batch-data/41.csv, 37 files out of an estimated total of 100
# Uploading batch-data/42.csv
# Uploaded batch-data/42.csv, 38 files out of an estimated total of 100
# Uploading batch-data/43.csv
# Uploaded batch-data/43.csv, 39 files out of an estimated total of 100
# Uploading batch-data/44.csv
# Uploaded batch-data/44.csv, 40 files out of an estimated total of 100
# Uploading batch-data/45.csv
# Uploaded batch-data/45.csv, 41 files out of an estimated total of 100
# Uploading batch-data/46.csv
# Uploaded batch-data/46.csv, 42 files out of an estimated total of 100
# Uploading batch-data/47.csv
# Uploaded batch-data/47.csv, 43 files out of an estimated total of 100
# Uploading batch-data/48.csv
# Uploaded batch-data/48.csv, 44 files out of an estimated total of 100
# Uploading batch-data/49.csv
# Uploaded batch-data/49.csv, 45 files out of an estimated total of 100
# Uploading batch-data/5.csv
# Uploaded batch-data/5.csv, 46 files out of an estimated total of 100
# Uploading batch-data/50.csv
# Uploaded batch-data/50.csv, 47 files out of an estimated total of 100
# Uploading batch-data/51.csv
# Uploaded batch-data/51.csv, 48 files out of an estimated total of 100
# Uploading batch-data/52.csv
# Uploaded batch-data/52.csv, 49 files out of an estimated total of 100
# Uploading batch-data/53.csv
# Uploaded batch-data/53.csv, 50 files out of an estimated total of 100
# Uploading batch-data/54.csv
# Uploaded batch-data/54.csv, 51 files out of an estimated total of 100
# Uploading batch-data/55.csv
# Uploaded batch-data/55.csv, 52 files out of an estimated total of 100
# Uploading batch-data/56.csv
# Uploaded batch-data/56.csv, 53 files out of an estimated total of 100
# Uploading batch-data/57.csv
# Uploaded batch-data/57.csv, 54 files out of an estimated total of 100
# Uploading batch-data/58.csv
# Uploaded batch-data/58.csv, 55 files out of an estimated total of 100
# Uploading batch-data/59.csv
# Uploaded batch-data/59.csv, 56 files out of an estimated total of 100
# Uploading batch-data/6.csv
# Uploaded batch-data/6.csv, 57 files out of an estimated total of 100
# Uploading batch-data/60.csv
# Uploaded batch-data/60.csv, 58 files out of an estimated total of 100
# Uploading batch-data/61.csv
# Uploaded batch-data/61.csv, 59 files out of an estimated total of 100
# Uploading batch-data/62.csv
# Uploaded batch-data/62.csv, 60 files out of an estimated total of 100
# Uploading batch-data/63.csv
# Uploaded batch-data/63.csv, 61 files out of an estimated total of 100
# Uploading batch-data/64.csv
# Uploaded batch-data/64.csv, 62 files out of an estimated total of 100
# Uploading batch-data/65.csv
# Uploaded batch-data/65.csv, 63 files out of an estimated total of 100
# Uploading batch-data/66.csv
# Uploaded batch-data/66.csv, 64 files out of an estimated total of 100
# Uploading batch-data/67.csv
# Uploaded batch-data/67.csv, 65 files out of an estimated total of 100
# Uploading batch-data/68.csv
# Uploaded batch-data/68.csv, 66 files out of an estimated total of 100
# Uploading batch-data/69.csv
# Uploaded batch-data/69.csv, 67 files out of an estimated total of 100
# Uploading batch-data/7.csv
# Uploaded batch-data/7.csv, 68 files out of an estimated total of 100
# Uploading batch-data/70.csv
# Uploaded batch-data/70.csv, 69 files out of an estimated total of 100
# Uploading batch-data/71.csv
# Uploaded batch-data/71.csv, 70 files out of an estimated total of 100
# Uploading batch-data/72.csv
# Uploaded batch-data/72.csv, 71 files out of an estimated total of 100
# Uploading batch-data/73.csv
# Uploaded batch-data/73.csv, 72 files out of an estimated total of 100
# Uploading batch-data/74.csv
# Uploaded batch-data/74.csv, 73 files out of an estimated total of 100
# Uploading batch-data/75.csv
# Uploaded batch-data/75.csv, 74 files out of an estimated total of 100
# Uploading batch-data/76.csv
# Uploaded batch-data/76.csv, 75 files out of an estimated total of 100
# Uploading batch-data/77.csv
# Uploaded batch-data/77.csv, 76 files out of an estimated total of 100
# Uploading batch-data/78.csv
# Uploaded batch-data/78.csv, 77 files out of an estimated total of 100
# Uploading batch-data/79.csv
# Uploaded batch-data/79.csv, 78 files out of an estimated total of 100
# Uploading batch-data/8.csv
# Uploaded batch-data/8.csv, 79 files out of an estimated total of 100
# Uploading batch-data/80.csv
# Uploaded batch-data/80.csv, 80 files out of an estimated total of 100
# Uploading batch-data/81.csv
# Uploaded batch-data/81.csv, 81 files out of an estimated total of 100
# Uploading batch-data/82.csv
# Uploaded batch-data/82.csv, 82 files out of an estimated total of 100
# Uploading batch-data/83.csv
# Uploaded batch-data/83.csv, 83 files out of an estimated total of 100
# Uploading batch-data/84.csv
# Uploaded batch-data/84.csv, 84 files out of an estimated total of 100
# Uploading batch-data/85.csv
# Uploaded batch-data/85.csv, 85 files out of an estimated total of 100
# Uploading batch-data/86.csv
# Uploaded batch-data/86.csv, 86 files out of an estimated total of 100
# Uploading batch-data/87.csv
# Uploaded batch-data/87.csv, 87 files out of an estimated total of 100
# Uploading batch-data/88.csv
# Uploaded batch-data/88.csv, 88 files out of an estimated total of 100
# Uploading batch-data/89.csv
# Uploaded batch-data/89.csv, 89 files out of an estimated total of 100
# Uploading batch-data/9.csv
# Uploaded batch-data/9.csv, 90 files out of an estimated total of 100
# Uploading batch-data/90.csv
# Uploaded batch-data/90.csv, 91 files out of an estimated total of 100
# Uploading batch-data/91.csv
# Uploaded batch-data/91.csv, 92 files out of an estimated total of 100
# Uploading batch-data/92.csv
# Uploaded batch-data/92.csv, 93 files out of an estimated total of 100
# Uploading batch-data/93.csv
# Uploaded batch-data/93.csv, 94 files out of an estimated total of 100
# Uploading batch-data/94.csv
# Uploaded batch-data/94.csv, 95 files out of an estimated total of 100
# Uploading batch-data/95.csv
# Uploaded batch-data/95.csv, 96 files out of an estimated total of 100
# Uploading batch-data/96.csv
# Uploaded batch-data/96.csv, 97 files out of an estimated total of 100
# Uploading batch-data/97.csv
# Uploaded batch-data/97.csv, 98 files out of an estimated total of 100
# Uploading batch-data/98.csv
# Uploaded batch-data/98.csv, 99 files out of an estimated total of 100
# Uploading batch-data/99.csv
# Uploaded batch-data/99.csv, 100 files out of an estimated total of 100
# Uploaded 100 files
# Done!

# %% [markdown]
# ## Create compute
#
# We'll need a compute context for the pipeline, so we'll use the following code to specify an Azure Machine Learning compute cluster (it will be created if it doesn't already exist).
#
# > **Important**: Change *your-compute-cluster* to the name of your compute cluster in the code below before running it! Cluster names must be globally unique names between 2 to 16 characters in length. Valid characters are letters, digits, and the - character.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "mlnodeclustr-alv"

try:
    # Check for existing compute target
    inference_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        inference_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        inference_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster, use it.

# %% [markdown]
# > **Note**: Compute instances and clusters are based on standard Azure virtual machine images. For this exercise, the *Standard_DS11_v2* image is recommended to achieve the optimal balance of cost and performance. If your subscription has a quota that does not include this image, choose an alternative image; but bear in mind that a larger image may incur higher cost and a smaller image may not be sufficient to complete the tasks. Alternatively, ask your Azure administrator to extend your quota.
#
# ## Create a pipeline for batch inferencing
#
# Now we're ready to define the pipeline we'll use for batch inferencing. Our pipeline will need Python code to perform the batch inferencing, so let's create a folder where we can keep all the files used by the pipeline:

# %%
import os
# Create a folder for the experiment files
experiment_folder = 'alvianda-car-price-predict-py'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# batch_pipeline

# %% [markdown]
# Now we'll create a Python script to do the actual work, and save it in the pipeline folder:

# %%
# %%writefile $experiment_folder/batch_diabetes.py
import os
import numpy as np
from azureml.core import Model
import joblib


def init():
    # Runs when the pipeline step is initialized
    global model

    # load the model
    model_path = Model.get_model_path('diabetes_model')
    model = joblib.load(model_path)


def run(mini_batch):
    # This runs for each batch
    resultList = []

    # process each file in the batch
    for f in mini_batch:
        # Read the comma-delimited data into an array
        data = np.genfromtxt(f, delimiter=',')
        print(data[20])
        # Reshape into a 2-dimensional array for prediction (model expects multiple items)
        prediction = model.predict(data.reshape(1, -1))
        # Append prediction to results
        resultList.append("{}: {}".format(os.path.basename(f), prediction[0]))
    return resultList
# Out:
# Writing batch_pipeline/batch_diabetes.py

# %% [markdown]
# The pipeline will need an environment in which to run, so we'll create a Conda specification that includes the packages that the code uses.

# %%
# %%writefile $experiment_folder/batch_environment.yml
# name: batch_environment
# dependencies:
# - python=3.6.2
# - scikit-learn
# - pip
# - pip:
#   - azureml-defaults
# Out:
# Writing batch_pipeline/batch_environment.yml

# %% [markdown]
# Next we'll define a run context that includes the Conda environment.

# %%
from azureml.core import Environment
from azureml.core.runconfig import DEFAULT_CPU_IMAGE

# Create an Environment for the experiment
batch_env = Environment.from_conda_specification("experiment_env", experiment_folder + "/batch_environment.yml")
batch_env.docker.base_image = DEFAULT_CPU_IMAGE
print('Configuration ready.')
# Out:
# Configuration ready.

# %% [markdown]
# You're going to use a pipeline to run the batch prediction script, generate predictions from the input data, and save the results as a text file in the output folder. To do this, you can use a **ParallelRunStep**, which enables the batch data to be processed in parallel and the results collated in a single output file named *parallel_run_step.txt*.

# %%
from azureml.pipeline.steps import ParallelRunConfig, ParallelRunStep
from azureml.data import OutputFileDatasetConfig

output_dir = OutputFileDatasetConfig(name='inferences')

parallel_run_config = ParallelRunConfig(
    source_directory=experiment_folder,
    entry_script="batch_diabetes.py",
    mini_batch_size="5",
    error_threshold=10,
    output_action="append_row",
    environment=batch_env,
    compute_target=inference_cluster,
    node_count=2)

parallelrun_step = ParallelRunStep(
    name='batch-score-diabetes',
    parallel_run_config=parallel_run_config,
    inputs=[batch_data_set.as_named_input('diabetes_batch')],
    output=output_dir,
    arguments=[],
    allow_reuse=True
)

print('Steps defined')
# Out:
# Steps defined

# %% [markdown]
# Now it's time to put the step into a pipeline, and run it.
#
# > **Note**: This may take some time!

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline

pipeline = Pipeline(workspace=ws, steps=[parallelrun_step])
pipeline_run = Experiment(ws, 'mslearn-diabetes-batch').submit(pipeline)
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step batch-score-diabetes [da87b052][36f18142-e905-48b3-93b7-47a923d60f85], (This step will run and generate new outputs)
# Submitted PipelineRun 01fc8b34-d087-4c55-ad1e-2e814ada7eee
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/01fc8b34-d087-4c55-ad1e-2e814ada7eee?wsid=/subscriptions/b55b31b5-96d1-46b1-b8df-55cda31eae9f/resourcegroups/mlresourcegroup/workspaces/mlresource-aml&tid=0b9b90da-3fe1-457a-b340-f1b67e1024fb
# PipelineRunId: 01fc8b34-d087-4c55-ad1e-2e814ada7eee
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/01fc8b34-d087-4c55-ad1e-2e814ada7eee?wsid=/subscriptions/b55b31b5-96d1-46b1-b8df-55cda31eae9f/resourcegroups/mlresourcegroup/workspaces/mlresource-aml&tid=0b9b90da-3fe1-457a-b340-f1b67e1024fb
# PipelineRun Status: Running
#
#
# StepRunId: 27a8306a-23dc-4523-a7a5-ff46f74d4957
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/27a8306a-23dc-4523-a7a5-ff46f74d4957?wsid=/subscriptions/b55b31b5-96d1-46b1-b8df-55cda31eae9f/resourcegroups/mlresourcegroup/workspaces/mlresource-aml&tid=0b9b90da-3fe1-457a-b340-f1b67e1024fb
# StepRun( batch-score-diabetes ) Status: NotStarted
# StepRun( batch-score-diabetes ) Status: Queued
# StepRun( batch-score-diabetes ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2022/02/09 15:39:00 Downloading source code...
# 2022/02/09 15:39:01 Finished downloading source code
# 2022/02/09 15:39:01 Creating Docker network: acb_default_network, driver: 'bridge'
# 2022/02/09 15:39:01 Successfully set up Docker network: acb_default_network
# 2022/02/09 15:39:01 Setting up Docker configuration...
# 2022/02/09 15:39:02 Successfully set up Docker configuration
# 2022/02/09 15:39:02 Logging in to registry: 300d7958723647f99b6c4410b620bfe0.azurecr.io
# 2022/02/09 15:39:03 Successfully logged into 300d7958723647f99b6c4410b620bfe0.azurecr.io
# 2022/02/09 15:39:03 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/02/09 15:39:03 Scanning for dependencies...
# 2022/02/09 15:39:04 Successfully scanned dependencies
# 2022/02/09 15:39:04 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/21 : FROM mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20211124.v1@sha256:4a11079816df82134801c513f323799acad2cbef525ef7a5361278d9b74b1d14
# mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20211124.v1@sha256:4a11079816df82134801c513f323799acad2cbef525ef7a5361278d9b74b1d14: Pulling from azureml/openmpi3.1.2-ubuntu18.04
# 284055322776: Already exists
# 56c2761c3a56: Pulling fs layer
# e7dff8330ff9: Pulling fs layer
# c782690959f6: Pulling fs layer
# 722c34119f7e: Pulling fs layer
# 2df507734fe8: Pulling fs layer
# 858f3d745b66: Pulling fs layer
# 7c1ed34d7266: Pulling fs layer
# 1ef5f8a4fad5: Pulling fs layer
# 2df507734fe8: Waiting
# 858f3d745b66: Waiting
# 7c1ed34d7266: Waiting
# 1ef5f8a4fad5: Waiting
# 722c34119f7e: Waiting
# e7dff8330ff9: Verifying Checksum
# e7dff8330ff9: Download complete
# c782690959f6: Verifying Checksum
# c782690959f6: Download complete
# 2df507734fe8: Verifying Checksum
# 2df507734fe8: Download complete
# 56c2761c3a56: Verifying Checksum
# 56c2761c3a56: Download complete
# 858f3d745b66: Verifying Checksum
# 858f3d745b66: Download complete
# 1ef5f8a4fad5: Verifying Checksum
# 1ef5f8a4fad5: Download complete
# 7c1ed34d7266: Verifying Checksum
# 7c1ed34d7266: Download complete
# 722c34119f7e: Verifying Checksum
# 722c34119f7e: Download complete
# 56c2761c3a56: Pull complete
# e7dff8330ff9: Pull complete
# c782690959f6: Pull complete
# 722c34119f7e: Pull complete
# 2df507734fe8: Pull complete
# 858f3d745b66: Pull complete
# 7c1ed34d7266: Pull complete
# 1ef5f8a4fad5: Pull complete
# Digest: sha256:4a11079816df82134801c513f323799acad2cbef525ef7a5361278d9b74b1d14
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20211124.v1@sha256:4a11079816df82134801c513f323799acad2cbef525ef7a5361278d9b74b1d14
#  ---> 332d3aa8a60a
# Step 2/21 : USER root
#  ---> Running in 78622445a6e7
# Removing intermediate container 78622445a6e7
#  ---> 1520c4e69d1a
# Step 3/21 : RUN mkdir -p $HOME/.cache
#  ---> Running in ca2210a69dc1
# Removing intermediate container ca2210a69dc1
#  ---> 0b72c47fd4ed
# Step 4/21 : WORKDIR /
#  ---> Running in 5eae90673eee
# Removing intermediate container 5eae90673eee
#  ---> 468c63d12d2c
# Step 5/21 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 0e37687625b5
# Step 6/21 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 0148a9d69f0e
# Removing intermediate container 0148a9d69f0e
#  ---> d187eb080d30
# Step 7/21 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> a7292b9768b4
# Step 8/21 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 4eecc328a4ee
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# openssl-1.0.2u       | 2.2 MB    |            |   0%
# openssl-1.0.2u       | 2.2 MB    | ########## | 100%
# openssl-1.0.2u       | 2.2 MB    | ########## | 100%
#
# libgfortran4-7.5.0   | 995 KB    |            |   0%
# libgfortran4-7.5.0   | 995 KB    | ########## | 100%
#
# mkl-service-2.3.0    | 52 KB     |            |   0%
# mkl-service-2.3.0    | 52 KB     | ########## | 100%
#
# numpy-1.19.2         | 22 KB     |            |   0%
# numpy-1.19.2         | 22 KB     | ########## | 100%
#
# libgomp-9.3.0        | 311 KB    |            |   0%
# libgomp-9.3.0        | 311 KB    | ########## | 100%
#
# libedit-3.1          | 151 KB    |            |   0%
# libedit-3.1          | 151 KB    | ########## | 100%
#
# numpy-base-1.19.2    | 4.1 MB    |            |   0%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
#
# xz-5.2.5             | 341 KB    |            |   0%
# xz-5.2.5             | 341 KB    | ########## | 100%
#
# zlib-1.2.11          | 108 KB    |            |   0%
# zlib-1.2.11          | 108 KB    | ########## | 100%
#
# mkl_random-1.1.1     | 327 KB    |            |   0%
# mkl_random-1.1.1     | 327 KB    | ########## | 100%
#
# pip-21.2.2           | 1.8 MB    |            |   0%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
#
# scikit-learn-0.24.2  | 5.2 MB    |            |   0%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
#
# libgcc-ng-9.3.0      | 4.8 MB    |            |   0%
# libgcc-ng-9.3.0      | 4.8 MB    | ########## | 100%
# libgcc-ng-9.3.0      | 4.8 MB    | ########## | 100%
#
# wheel-0.37.1         | 33 KB     |            |   0%
# wheel-0.37.1         | 33 KB     | ########## | 100%
#
# joblib-1.0.1         | 208 KB    |            |   0%
# joblib-1.0.1         | 208 KB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# libstdcxx-ng-9.3.0   | 3.1 MB    |            |   0%
# libstdcxx-ng-9.3.0   | 3.1 MB    | ########## | 100%
#
# sqlite-3.23.1        | 808 KB    |            |   0%
# sqlite-3.23.1        | 808 KB    | ########## | 100%
#
# mkl_fft-1.3.0        | 170 KB    |            |   0%
# mkl_fft-1.3.0        | 170 KB    | ########## | 100%
#
# libffi-3.2.1         | 48 KB     |            |   0%
# libffi-3.2.1         | 48 KB     | ########## | 100%
#
# libgfortran-ng-7.5.0 | 22 KB     |            |   0%
# libgfortran-ng-7.5.0 | 22 KB     | ########## | 100%
#
# ca-certificates-2021 | 115 KB    |            |   0%
# ca-certificates-2021 | 115 KB    | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# tk-8.6.11            | 3.0 MB    |            |   0%
# tk-8.6.11            | 3.0 MB    | ########## | 100%
# tk-8.6.11            | 3.0 MB    | ########## | 100%
#
# scipy-1.5.2          | 14.4 MB   |            |   0%
# scipy-1.5.2          | 14.4 MB   | #####2     |  53%
# scipy-1.5.2          | 14.4 MB   | ########## | 100%
# scipy-1.5.2          | 14.4 MB   | ########## | 100%
#
# mkl-2020.2           | 138.3 MB  |            |   0%
# mkl-2020.2           | 138.3 MB  | 7          |   7%
# mkl-2020.2           | 138.3 MB  | #6         |  17%
# mkl-2020.2           | 138.3 MB  | ##6        |  27%
# mkl-2020.2           | 138.3 MB  | ###5       |  36%
# mkl-2020.2           | 138.3 MB  | ####5      |  45%
# mkl-2020.2           | 138.3 MB  | #####3     |  54%
# mkl-2020.2           | 138.3 MB  | ######3    |  63%
# mkl-2020.2           | 138.3 MB  | #######3   |  73%
# mkl-2020.2           | 138.3 MB  | ########2  |  82%
# mkl-2020.2           | 138.3 MB  | #########1 |  92%
# mkl-2020.2           | 138.3 MB  | ########## | 100%
#
# _openmp_mutex-4.5    | 22 KB     |            |   0%
# _openmp_mutex-4.5    | 22 KB     | ########## | 100%
#
# readline-7.0         | 848 KB    |            |   0%
# readline-7.0         | 848 KB    | ########## | 100%
#
# python-3.6.2         | 23.6 MB   |            |   0%
# python-3.6.2         | 23.6 MB   | ####4      |  44%
# python-3.6.2         | 23.6 MB   | ########8  |  88%
# python-3.6.2         | 23.6 MB   | ########## | 100%
#
# intel-openmp-2022.0. | 4.2 MB    |            |   0%
# intel-openmp-2022.0. | 4.2 MB    | ########## | 100%
# intel-openmp-2022.0. | 4.2 MB    | ########## | 100%
#
# six-1.16.0           | 18 KB     |            |   0%
# six-1.16.0           | 18 KB     | ########## | 100%
#
# threadpoolctl-2.2.0  | 16 KB     |            |   0%
# threadpoolctl-2.2.0  | 16 KB     | ########## | 100%
#
# ncurses-6.0          | 781 KB    |            |   0%
# ncurses-6.0          | 781 KB    | ########## | 100%
# ncurses-6.0          | 781 KB    | ########## | 100%
#
# certifi-2021.5.30    | 139 KB    |            |   0%
# certifi-2021.5.30    | 139 KB    | ########## | 100%
#
# setuptools-58.0.4    | 788 KB    |            |   0%
# setuptools-58.0.4    | 788 KB    | ########## | 100%
# setuptools-58.0.4    | 788 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.z52ti40p.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.38.0-py3-none-any.whl (3.0 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.38.0
#   Downloading azureml_dataset_runtime-1.38.0-py3-none-any.whl (3.5 kB)
# Collecting azureml-inference-server-http~=0.4.1
#   Downloading azureml_inference_server_http-0.4.2-py3-none-any.whl (38 kB)
# Collecting azureml-core~=1.38.0
#   Downloading azureml_core-1.38.0-py3-none-any.whl (2.5 MB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting pkginfo
#   Downloading pkginfo-1.8.2-py2.py3-none-any.whl (26 kB)
# Collecting argcomplete<2.0
#   Downloading argcomplete-1.12.3-py2.py3-none-any.whl (38 kB)
# Collecting adal<=1.2.7,>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting contextlib2<22.0.0
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.3.0-py3-none-any.whl (16 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting jmespath<1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting pyopenssl<22.0.0
#   Downloading pyOpenSSL-21.0.0-py2.py3-none-any.whl (55 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting humanfriendly<11.0,>=4.7
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Collecting azure-mgmt-storage<20.0.0,>=16.0.0
#   Downloading azure_mgmt_storage-19.0.0-py2.py3-none-any.whl (1.8 MB)
# Collecting msal-extensions<0.4,>=0.3.0
#   Downloading msal_extensions-0.3.1-py2.py3-none-any.whl (18 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting ndg-httpsclient<=0.5.1
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting azure-core<1.22
#   Downloading azure_core-1.21.1-py2.py3-none-any.whl (178 kB)
# Collecting paramiko<3.0.0,>=2.0.8
#   Downloading paramiko-2.9.2-py2.py3-none-any.whl (210 kB)
# Collecting urllib3<=1.26.7,>=1.23
#   Downloading urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
# Collecting knack~=0.8.2
#   Downloading knack-0.8.2-py3-none-any.whl (59 kB)
# Collecting azure-mgmt-resource<21.0.0,>=15.0.0
#   Downloading azure_mgmt_resource-20.1.0-py3-none-any.whl (2.3 MB)
# Collecting azure-mgmt-containerregistry<9.0.0,>=8.2.0
#   Downloading azure_mgmt_containerregistry-8.2.0-py2.py3-none-any.whl (928 kB)
# Collecting msrestazure<=0.6.4,>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting python-dateutil<3.0.0,>=2.7.3
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.1.0-py2.py3-none-any.whl (38 kB)
# Collecting azure-mgmt-keyvault<10.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-9.3.0-py2.py3-none-any.whl (412 kB)
# Collecting msal<2.0.0,>=1.15.0
#   Downloading msal-1.16.0-py2.py3-none-any.whl (78 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<37.0.0
#   Downloading cryptography-36.0.1-cp36-abi3-manylinux_2_24_x86_64.whl (3.6 MB)
# Collecting packaging<22.0,>=20.0
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting requests[socks]<3.0.0,>=2.19.1
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Collecting docker<6.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
# Collecting pytz
#   Downloading pytz-2021.3-py2.py3-none-any.whl (503 kB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting importlib-metadata<5,>=0.23
#   Downloading importlib_metadata-4.8.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: six>=1.11.0 in /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib/python3.6/site-packages (from azure-core<1.22->azureml-core~=1.38.0->azureml-defaults->-r /azureml-environment-setup/condaenv.z52ti40p.requirements.txt (line 1)) (1.16.0)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.3.0-py2.py3-none-any.whl (25 kB)
# Collecting pyarrow<4.0.0,>=0.17.0
#   Downloading pyarrow-3.0.0-cp36-cp36m-manylinux2014_x86_64.whl (20.7 MB)
# Collecting azureml-dataprep<2.27.0a,>=2.26.0a
#   Downloading azureml_dataprep-2.26.0-py3-none-any.whl (39.4 MB)
# Requirement already satisfied: numpy!=1.19.3 in /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse]~=1.38.0->azureml-defaults->-r /azureml-environment-setup/condaenv.z52ti40p.requirements.txt (line 1)) (1.19.2)
# Collecting fusepy<4.0.0,>=3.0.1
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting cloudpickle<3.0.0,>=1.1.0
#   Downloading cloudpickle-2.0.0-py3-none-any.whl (25 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.23-py3-none-manylinux1_x86_64.whl (29.3 MB)
# Collecting azureml-dataprep-native<39.0.0,>=38.0.0
#   Downloading azureml_dataprep_native-38.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting azureml-dataprep-rslex~=2.2.0dev0
#   Downloading azureml_dataprep_rslex-2.2.0-cp36-cp36m-manylinux2010_x86_64.whl (13.4 MB)
# Collecting azure-identity==1.7.0
#   Downloading azure_identity-1.7.0-py2.py3-none-any.whl (129 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting inference-schema==1.3.0
#   Downloading inference_schema-1.3.0-py3-none-any.whl (19 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting gunicorn==20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Collecting Werkzeug>=0.14
#   Downloading Werkzeug-2.0.3-py3-none-any.whl (289 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-3.0.3-py3-none-any.whl (133 kB)
# Collecting click>=5.1
#   Downloading click-8.0.3-py3-none-any.whl (97 kB)
# Requirement already satisfied: setuptools>=3.0 in /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib/python3.6/site-packages (from gunicorn==20.1.0->azureml-inference-server-http~=0.4.1->azureml-defaults->-r /azureml-environment-setup/condaenv.z52ti40p.requirements.txt (line 1)) (58.0.4)
# Collecting wrapt<=1.12.1,>=1.11.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.15.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (405 kB)
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.2.3-py3-none-any.whl (53 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.6.0-py2.py3-none-any.whl (19 kB)
# Collecting typing-extensions>=3.6.4
#   Downloading typing_extensions-4.0.1-py3-none-any.whl (22 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.6.0-py3-none-any.whl (5.3 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (30 kB)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting tabulate
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Collecting pygments
#   Downloading Pygments-2.11.2-py3-none-any.whl (1.1 MB)
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (603 kB)
# Collecting portalocker<3,>=1.0
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib/python3.6/site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.38.0->azureml-defaults->-r /azureml-environment-setup/condaenv.z52ti40p.requirements.txt (line 1)) (2021.5.30)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting pyparsing!=3.0.5,>=2.0.2
#   Downloading pyparsing-3.0.7-py3-none-any.whl (98 kB)
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-3.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (61 kB)
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.11-py3-none-any.whl (39 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Collecting PySocks!=1.5.7,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.7.1-py3-none-any.whl (54 kB)
# Collecting dataclasses
#   Downloading dataclasses-0.8-py3-none-any.whl (19 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Building wheels for collected packages: json-logging-py, fusepy, wrapt
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=c1ae328b7a707f537731462312f80f8a4f0f32bee19d6630d07ad45ae131e32e
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10503 sha256=8a0c5dc72e84529abd1a775ea8367a0050d7d3d3481f71e408a445657e3d1ed1
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp36-cp36m-linux_x86_64.whl size=69942 sha256=f80f8bb8ebf9e41802030cb8829dd8ac364d233d3730dc3e57f1e8bd070945bd
#   Stored in directory: /root/.cache/pip/wheels/32/42/7f/23cae9ff6ef66798d00dc5d659088e57dbba01566f6c60db63
# Successfully built json-logging-py fusepy wrapt
# Installing collected packages: pycparser, cffi, urllib3, PyJWT, idna, cryptography, charset-normalizer, requests, portalocker, oauthlib, msal, zipp, typing-extensions, requests-oauthlib, python-dateutil, msal-extensions, isodate, distro, azure-core, msrest, MarkupSafe, importlib-metadata, dotnetcore2, dataclasses, cloudpickle, azureml-dataprep-rslex, azureml-dataprep-native, azure-identity, adal, wrapt, Werkzeug, websocket-client, tabulate, pyyaml, pytz, PySocks, pyparsing, pyopenssl, pynacl, pygments, pyasn1, pyarrow, msrestazure, jmespath, Jinja2, jeepney, itsdangerous, colorama, click, bcrypt, backports.weakref, azureml-dataprep, azure-mgmt-core, azure-common, argcomplete, SecretStorage, pkginfo, pathspec, paramiko, packaging, ndg-httpsclient, knack, jsonpickle, inference-schema, humanfriendly, gunicorn, fusepy, flask, docker, contextlib2, backports.tempfile, azureml-dataset-runtime, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, azure-graphrbac, applicationinsights, json-logging-py, configparser, azureml-inference-server-http, azureml-core, azureml-defaults
# Successfully installed Jinja2-3.0.3 MarkupSafe-2.0.1 PyJWT-2.3.0 PySocks-1.7.1 SecretStorage-3.3.1 Werkzeug-2.0.3 adal-1.2.7 applicationinsights-0.11.10 argcomplete-1.12.3 azure-common-1.1.28 azure-core-1.21.1 azure-graphrbac-0.61.1 azure-identity-1.7.0 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-8.2.0 azure-mgmt-core-1.3.0 azure-mgmt-keyvault-9.3.0 azure-mgmt-resource-20.1.0 azure-mgmt-storage-19.0.0 azureml-core-1.38.0 azureml-dataprep-2.26.0 azureml-dataprep-native-38.0.0 azureml-dataprep-rslex-2.2.0 azureml-dataset-runtime-1.38.0 azureml-defaults-1.38.0 azureml-inference-server-http-0.4.2 backports.tempfile-1.0 backports.weakref-1.0.post1 bcrypt-3.2.0 cffi-1.15.0 charset-normalizer-2.0.11 click-8.0.3 cloudpickle-2.0.0 colorama-0.4.4 configparser-3.7.4 contextlib2-21.6.0 cryptography-36.0.1 dataclasses-0.8 distro-1.6.0 docker-5.0.3 dotnetcore2-2.1.23 flask-1.0.3 fusepy-3.0.1 gunicorn-20.1.0 humanfriendly-10.0 idna-3.3 importlib-metadata-4.8.3 inference-schema-1.3.0 isodate-0.6.1 itsdangerous-2.0.1 jeepney-0.7.1 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.1.0 knack-0.8.2 msal-1.16.0 msal-extensions-0.3.1 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.2.0 packaging-21.3 paramiko-2.9.2 pathspec-0.9.0 pkginfo-1.8.2 portalocker-2.3.2 pyarrow-3.0.0 pyasn1-0.4.8 pycparser-2.21 pygments-2.11.2 pynacl-1.5.0 pyopenssl-21.0.0 pyparsing-3.0.7 python-dateutil-2.8.2 pytz-2021.3 pyyaml-6.0 requests-2.27.1 requests-oauthlib-1.3.1 tabulate-0.8.9 typing-extensions-4.0.1 urllib3-1.26.7 websocket-client-1.2.3 wrapt-1.12.1 zipp-3.6.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
#
# Removing intermediate container 4eecc328a4ee
#  ---> fd68cde45ad1
# Step 9/21 : ENV PATH /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/bin:$PATH
#  ---> Running in d2b6d477264f
# Removing intermediate container d2b6d477264f
#  ---> 19db6df0ffc7
# Step 10/21 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> ce99b6cb7dfa
# Step 11/21 : RUN echo "Copying environment context"
#  ---> Running in d7e917107512
# Copying environment context
# Removing intermediate container d7e917107512
#  ---> 69cb321d1789
# Step 12/21 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 6798b0483f01
# Step 13/21 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d
#  ---> Running in ef5bebf2831d
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container ef5bebf2831d
#  ---> 2bdd4313aada
# Step 14/21 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d
#  ---> Running in 3a2186442b3b
# Removing intermediate container 3a2186442b3b
#  ---> dfa1a5481347
# Step 15/21 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib:$LD_LIBRARY_PATH
#  ---> Running in 7b5a73d9c103
# Removing intermediate container 7b5a73d9c103
#  ---> 791a66dbe956
# Step 16/21 : ENV CONDA_DEFAULT_ENV=azureml_e220b045f6c3c3008b1a386af067185d CONDA_PREFIX=/azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d
#  ---> Running in e41e9d7366ec
# Removing intermediate container e41e9d7366ec
#  ---> b34a049b865d
# Step 17/21 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 8ffa9d143e74
# Step 18/21 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in dc88e2dd3569
# Removing intermediate container dc88e2dd3569
#  ---> 82ffc9f8d1f4
# Step 19/21 : RUN rm -rf azureml-environment-setup
#  ---> Running in 5ee62daa1b85
# Removing intermediate container 5ee62daa1b85
#  ---> a7ddc4f0b86e
# Step 20/21 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 182a2ce52a31
# Removing intermediate container 182a2ce52a31
#  ---> d510ec3b0f37
# Step 21/21 : CMD ["bash"]
#  ---> Running in 4e219042722d
# Removing intermediate container 4e219042722d
#  ---> fc6f07e8fd06
# Successfully built fc6f07e8fd06
# Successfully tagged 300d7958723647f99b6c4410b620bfe0.azurecr.io/azureml/azureml_2c71eeae7c7e5101680a3d50bbbe0cc2:latest
# Successfully tagged 300d7958723647f99b6c4410b620bfe0.azurecr.io/azureml/azureml_2c71eeae7c7e5101680a3d50bbbe0cc2:1
# 2022/02/09 15:40:55 Successfully executed container: acb_step_0
# 2022/02/09 15:40:55 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/02/09 15:40:55 Pushing image: 300d7958723647f99b6c4410b620bfe0.azurecr.io/azureml/azureml_2c71eeae7c7e5101680a3d50bbbe0cc2:1, attempt 1
# The push refers to repository [300d7958723647f99b6c4410b620bfe0.azurecr.io/azureml/azureml_2c71eeae7c7e5101680a3d50bbbe0cc2]
# 8bb002480e1f: Preparing
# c87181a8282d: Preparing
# 4d7412294e8c: Preparing
# 526bba721a79: Preparing
# b25cb7225f1d: Preparing
# e2db4324de13: Preparing
# 6b79fe1d2415: Preparing
# e66b3570abba: Preparing
# e06e24006849: Preparing
# 534024d6a565: Preparing
# 3c50432f3f31: Preparing
# 311c5d6a5fbd: Preparing
# 510d9bebb038: Preparing
# ae7a6b62e247: Preparing
# 98fed88a80e7: Preparing
# e2015ea1a701: Preparing
# f7df5bbbf80f: Preparing
# 17773ff7b0e9: Preparing
# 824bf068fd3d: Preparing
# e2db4324de13: Waiting
# 6b79fe1d2415: Waiting
# e66b3570abba: Waiting
# e06e24006849: Waiting
# 534024d6a565: Waiting
# 3c50432f3f31: Waiting
# 311c5d6a5fbd: Waiting
# 510d9bebb038: Waiting
# ae7a6b62e247: Waiting
# 98fed88a80e7: Waiting
# e2015ea1a701: Waiting
# f7df5bbbf80f: Waiting
# 17773ff7b0e9: Waiting
# 824bf068fd3d: Waiting
# b25cb7225f1d: Pushed
# 526bba721a79: Pushed
# c87181a8282d: Pushed
# 4d7412294e8c: Pushed
# e66b3570abba: Pushed
# 6b79fe1d2415: Pushed
# e06e24006849: Pushed
# 8bb002480e1f: Pushed
# 534024d6a565: Pushed
# 3c50432f3f31: Pushed
# 311c5d6a5fbd: Pushed
# 510d9bebb038: Pushed
# ae7a6b62e247: Pushed
# f7df5bbbf80f: Pushed
# e2015ea1a701: Pushed
# 824bf068fd3d: Pushed
# 98fed88a80e7: Pushed
# 17773ff7b0e9: Pushed
#
# e2db4324de13: Pushed
# 1: digest: sha256:836c82c8a65f08fcb27a605f8b97e0f88652ff2a03e13099b7413711f6ae7eec size: 4307
# 2022/02/09 15:42:26 Successfully pushed image: 300d7958723647f99b6c4410b620bfe0.azurecr.io/azureml/azureml_2c71eeae7c7e5101680a3d50bbbe0cc2:1
# 2022/02/09 15:42:26 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/02/09 15:42:26 Pushing image: 300d7958723647f99b6c4410b620bfe0.azurecr.io/azureml/azureml_2c71eeae7c7e5101680a3d50bbbe0cc2:latest, attempt 1
# The push refers to repository [300d7958723647f99b6c4410b620bfe0.azurecr.io/azureml/azureml_2c71eeae7c7e5101680a3d50bbbe0cc2]
# 8bb002480e1f: Preparing
# c87181a8282d: Preparing
# 4d7412294e8c: Preparing
# 526bba721a79: Preparing
# b25cb7225f1d: Preparing
# e2db4324de13: Preparing
# 6b79fe1d2415: Preparing
# e66b3570abba: Preparing
# e06e24006849: Preparing
# 534024d6a565: Preparing
# 3c50432f3f31: Preparing
# 311c5d6a5fbd: Preparing
# 510d9bebb038: Preparing
# ae7a6b62e247: Preparing
# 98fed88a80e7: Preparing
# e2015ea1a701: Preparing
# f7df5bbbf80f: Preparing
# 17773ff7b0e9: Preparing
# 824bf068fd3d: Preparing
# e2db4324de13: Waiting
# 3c50432f3f31: Waiting
# 6b79fe1d2415: Waiting
# 311c5d6a5fbd: Waiting
# e66b3570abba: Waiting
# 510d9bebb038: Waiting
# ae7a6b62e247: Waiting
# e06e24006849: Waiting
# 98fed88a80e7: Waiting
# e2015ea1a701: Waiting
# 534024d6a565: Waiting
# f7df5bbbf80f: Waiting
# 17773ff7b0e9: Waiting
# 824bf068fd3d: Waiting
# 526bba721a79: Layer already exists
# 4d7412294e8c: Layer already exists
# b25cb7225f1d: Layer already exists
# 8bb002480e1f: Layer already exists
# c87181a8282d: Layer already exists
# e2db4324de13: Layer already exists
# 6b79fe1d2415: Layer already exists
# e06e24006849: Layer already exists
# e66b3570abba: Layer already exists
# 534024d6a565: Layer already exists
# 311c5d6a5fbd: Layer already exists
# 3c50432f3f31: Layer already exists
# 510d9bebb038: Layer already exists
# 98fed88a80e7: Layer already exists
# ae7a6b62e247: Layer already exists
# e2015ea1a701: Layer already exists
# f7df5bbbf80f: Layer already exists
# 17773ff7b0e9: Layer already exists
# 824bf068fd3d: Layer already exists
# latest: digest: sha256:836c82c8a65f08fcb27a605f8b97e0f88652ff2a03e13099b7413711f6ae7eec size: 4307
# 2022/02/09 15:42:27 Successfully pushed image: 300d7958723647f99b6c4410b620bfe0.azurecr.io/azureml/azureml_2c71eeae7c7e5101680a3d50bbbe0cc2:latest
# 2022/02/09 15:42:27 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 112.207270)
# 2022/02/09 15:42:27 Populating digests for step ID: acb_step_0...
# 2022/02/09 15:42:29 Successfully populated digests for step ID: acb_step_0
# 2022/02/09 15:42:29 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 90.756894)
# 2022/02/09 15:42:29 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 1.395809)
# 2022/02/09 15:42:29 The following dependencies were found:
# 2022/02/09 15:42:29
# - image:
#     registry: 300d7958723647f99b6c4410b620bfe0.azurecr.io
#     repository: azureml/azureml_2c71eeae7c7e5101680a3d50bbbe0cc2
#     tag: latest
#     digest: sha256:836c82c8a65f08fcb27a605f8b97e0f88652ff2a03e13099b7413711f6ae7eec
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20211124.v1
#     digest: sha256:4a11079816df82134801c513f323799acad2cbef525ef7a5361278d9b74b1d14
#   git: {}
# - image:
#     registry: 300d7958723647f99b6c4410b620bfe0.azurecr.io
#     repository: azureml/azureml_2c71eeae7c7e5101680a3d50bbbe0cc2
#     tag: "1"
#     digest: sha256:836c82c8a65f08fcb27a605f8b97e0f88652ff2a03e13099b7413711f6ae7eec
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20211124.v1
#     digest: sha256:4a11079816df82134801c513f323799acad2cbef525ef7a5361278d9b74b1d14
#   git: {}
#
#
# Run ID: ca3 was successful after 3m30s
# Streaming azureml-logs/55_azureml-execution-tvmps_25449a4c9f14b465a4eb4efea0ed998d7c9c94ae8bd3149f0936d8a3261c9bcd_d.txt
# ========================================================================================================================
# 2022-02-09T16:00:41Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/mlresource-aml/azureml/27a8306a-23dc-4523-a7a5-ff46f74d4957/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/mlresource-aml/azureml/27a8306a-23dc-4523-a7a5-ff46f74d4957/caches/workspaceblobstore -o ro --file-cache-timeout-in-seconds=1000000 --cache-size-mb=24745 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/mlresource-aml/azureml/27a8306a-23dc-4523-a7a5-ff46f74d4957/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2022-02-09T16:00:41Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/mlresource-aml/azureml/27a8306a-23dc-4523-a7a5-ff46f74d4957/mounts/workspaceblobstore -- stdout/stderr:
# 2022-02-09T16:00:41Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2022-02-09T16:00:41Z Starting output-watcher...
# 2022-02-09T16:00:42Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_e8d7932f60b5241e5c58f00d93ad098c
# 92473f7ef455: Pulling fs layer
# fb52bde70123: Pulling fs layer
# 64788f86be3f: Pulling fs layer
# 33f6d5f2e001: Pulling fs layer
# eeb715f1b6ae: Pulling fs layer
# fe519cf36537: Pulling fs layer
# 58ff99196c15: Pulling fs layer
# 9b13f06a8eff: Pulling fs layer
# 2d4e93adbf58: Pulling fs layer
# 6ee7c3767844: Pulling fs layer
# 62cfc3ccb8ab: Pulling fs layer
# 4a7af9d757ee: Pulling fs layer
# 4662634b7aa2: Pulling fs layer
# 806bc6687e26: Pulling fs layer
# 78da324cb516: Pulling fs layer
# 95047a01d57e: Pulling fs layer
# 7cb1a6cdc866: Pulling fs layer
# 2b051fd77e77: Pulling fs layer
# ba587e120ad3: Pulling fs layer
# 6ee7c3767844: Waiting
# 62cfc3ccb8ab: Waiting
# 4a7af9d757ee: Waiting
# 4662634b7aa2: Waiting
# 806bc6687e26: Waiting
# 78da324cb516: Waiting
# 95047a01d57e: Waiting
# 7cb1a6cdc866: Waiting
# 2b051fd77e77: Waiting
# ba587e120ad3: Waiting
# fe519cf36537: Waiting
# 58ff99196c15: Waiting
# 33f6d5f2e001: Waiting
# eeb715f1b6ae: Waiting
# 9b13f06a8eff: Waiting
# 2d4e93adbf58: Waiting
# fb52bde70123: Verifying Checksum
# fb52bde70123: Download complete
# 64788f86be3f: Verifying Checksum
# 64788f86be3f: Download complete
# 33f6d5f2e001: Verifying Checksum
# 33f6d5f2e001: Download complete
# fe519cf36537: Verifying Checksum
# fe519cf36537: Download complete
# 92473f7ef455: Verifying Checksum
# 92473f7ef455: Download complete
# 58ff99196c15: Verifying Checksum
# 58ff99196c15: Download complete
# eeb715f1b6ae: Verifying Checksum
# eeb715f1b6ae: Download complete
# 9b13f06a8eff: Verifying Checksum
# 9b13f06a8eff: Download complete
# 6ee7c3767844: Verifying Checksum
# 6ee7c3767844: Download complete
# 62cfc3ccb8ab: Verifying Checksum
# 62cfc3ccb8ab: Download complete
# 4a7af9d757ee: Verifying Checksum
# 4a7af9d757ee: Download complete
# 4662634b7aa2: Verifying Checksum
# 4662634b7aa2: Download complete
# 2d4e93adbf58: Verifying Checksum
# 2d4e93adbf58: Download complete
# 95047a01d57e: Verifying Checksum
# 95047a01d57e: Download complete
# 78da324cb516: Verifying Checksum
# 78da324cb516: Download complete
# 7cb1a6cdc866: Verifying Checksum
# 7cb1a6cdc866: Download complete
# 2b051fd77e77: Verifying Checksum
# 2b051fd77e77: Download complete
# ba587e120ad3: Verifying Checksum
# ba587e120ad3: Download complete
# 92473f7ef455: Pull complete
# 806bc6687e26: Verifying Checksum
# 806bc6687e26: Download complete
# fb52bde70123: Pull complete
# 64788f86be3f: Pull complete
# 33f6d5f2e001: Pull complete
# eeb715f1b6ae: Pull complete
# fe519cf36537: Pull complete
# 58ff99196c15: Pull complete
# 9b13f06a8eff: Pull complete
# 2d4e93adbf58: Pull complete
# 6ee7c3767844: Pull complete
# 62cfc3ccb8ab: Pull complete
# 4a7af9d757ee: Pull complete
# 4662634b7aa2: Pull complete
# 806bc6687e26: Pull complete
# 78da324cb516: Pull complete
# 95047a01d57e: Pull complete
# 7cb1a6cdc866: Pull complete
# 2b051fd77e77: Pull complete
# ba587e120ad3: Pull complete
# Digest: sha256:fa5a0434411f61f9191973238a617eed31ab52b0f2e9fe77079b976dda7044fc
# Status: Downloaded newer image for viennaglobal.azurecr.io/azureml/azureml_e8d7932f60b5241e5c58f00d93ad098c:latest
# viennaglobal.azurecr.io/azureml/azureml_e8d7932f60b5241e5c58f00d93ad098c:latest
# 2022-02-09T16:01:14Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2022-02-09T16:01:14Z Check if container 27a8306a-23dc-4523-a7a5-ff46f74d4957_DataSidecar already exist exited with 0,
#
# 94b039c87b904a12ca183b4e272808cd1205e96a580e190624f18dcaca976e5b
# 2022-02-09T16:01:15Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2022-02-09T16:01:15Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-1a25a7f91604a4b4883de7b80b61a156-16a0487d14988032-01 -sshRequired=false]
# 2022/02/09 16:01:15 Didn't get JobInfoJson from env, now read from file
# 2022/02/09 16:01:15 Suceeded read JobInfoJson from file
# 2022/02/09 16:01:15 Starting App Insight Logger for task:  containerSetup
# 2022/02/09 16:01:15 Version: 3.0.01853.0004 Branch: .SourceBranch Commit: df26c27
# 2022/02/09 16:01:15 Entered ContainerSetupTask - Preparing infiniband
# 2022/02/09 16:01:15 Starting infiniband setup
# 2022/02/09 16:01:15 Python Version found is Python 3.7.9
#
# 2022/02/09 16:01:15 Returning Python Version as 3.7
# 2022/02/09 16:01:15 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2022/02/09 16:01:15 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2022-02-09T16:01:15Z VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2022/02/09 16:01:15 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2022/02/09 16:01:15 Not setting up Infiniband in Container
# 2022/02/09 16:01:15 Not setting up Infiniband in Container
# 2022-02-09T16:01:15Z Not setting up Infiniband in Container
# 2022/02/09 16:01:15 Python Version found is Python 3.7.9
#
# 2022/02/09 16:01:15 Returning Python Version as 3.7
# 2022/02/09 16:01:15 sshd inside container not required for job, skipping setup.
# 2022/02/09 16:01:16 All App Insights Logs was sent successfully or the close timeout of 10 was reached
# 2022/02/09 16:01:16 App Insight Client has already been closed
# 2022/02/09 16:01:16 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2022-02-09T16:01:16Z Starting docker container succeeded.
# 2022-02-09T16:01:16Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
#
# Streaming azureml-logs/65_job_prep-tvmps_25449a4c9f14b465a4eb4efea0ed998d7c9c94ae8bd3149f0936d8a3261c9bcd_d.txt
# ===============================================================================================================
# [2022-02-09T16:01:18.099918] Entering job preparation.
# [2022-02-09T16:01:18.741936] Starting job preparation.
# [2022-02-09T16:01:18.741983] Extracting the control code.
# [2022-02-09T16:01:18.742312] Starting extract_project.
# [2022-02-09T16:01:18.742350] Starting to extract zip file.
# [2022-02-09T16:01:18.760976] Finished extracting zip file.
# [2022-02-09T16:01:18.764837] Using urllib.request Python 3.0 or later
# [2022-02-09T16:01:18.764886] Start fetching snapshots.
# [2022-02-09T16:01:18.764924] Start fetching snapshot.
# Starting the daemon thread to refresh tokens in background for process with pid = 53
# [2022-02-09T16:01:19.105865] Finished fetching snapshot.
# [2022-02-09T16:01:19.105909] Start fetching snapshot.
# [2022-02-09T16:01:27.069798] Finished fetching snapshot.
# [2022-02-09T16:01:27.069839] Finished fetching snapshots.
# [2022-02-09T16:01:27.069863] Finished extract_project.
# [2022-02-09T16:01:27.069933] Finished fetching and extracting the control code.
# [2022-02-09T16:01:27.077010] Start run_history_prep.
# [2022-02-09T16:01:27.085795] Job preparation is complete.
# [2022-02-09T16:01:27.086106] Entering Data Context Managers in Sidecar
# [2022-02-09T16:01:27.087064] Running Sidecar prep cmd...
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (azure-core 1.21.1 (/opt/miniconda/lib/python3.7/site-packages), Requirement.parse('azure-core<1.21')).
# [2022-02-09T16:01:27.386912] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlresource-aml/azureml/27a8306a-23dc-4523-a7a5-ff46f74d4957/wd/azureml/27a8306a-23dc-4523-a7a5-ff46f74d4957
# [2022-02-09T16:01:27.387731] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets"]}
# [2022-02-09T16:01:27.586] Enter __enter__ of DatasetContextManager
# [2022-02-09T16:01:27.587] SDK version: azureml-core==1.37.0.post1 azureml-dataprep==2.25.2. Session id: 3f5d2be6-c960-48cd-833c-cc63f3eea9d5. Run id: 27a8306a-23dc-4523-a7a5-ff46f74d4957.
# [2022-02-09T16:01:27.587] Processing 'diabetes_batch'.
# [2022-02-09T16:01:27.587] Mode: 'mount'.
# [2022-02-09T16:01:27.587] Path on compute is specified: 'False'.
# [2022-02-09T16:01:30.310] Processing dataset FileDataset
# {
#   "source": [
#     "('workspaceblobstore', 'batch-data/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "be4d3d64-64dd-4372-ac8b-35c2523cb4c6",
#     "name": "batch-data",
#     "version": 1,
#     "description": "batch data",
#     "workspace": "Workspace.create(name='mlresource-aml', subscription_id='b55b31b5-96d1-46b1-b8df-55cda31eae9f', resource_group='mlresourcegroup')"
#   }
# }
# [2022-02-09T16:01:33.649] Mounting diabetes_batch to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlresource-aml/azureml/27a8306a-23dc-4523-a7a5-ff46f74d4957/wd/diabetes_batch_be4d3d64-64dd-4372-ac8b-35c2523cb4c6 as folder.
# [2022-02-09T16:01:33.649] Processing 'inferences'.
# [2022-02-09T16:01:33.649] Mode: 'mount'.
# [2022-02-09T16:01:33.649] Path on compute is specified: '/mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlresource-aml/azureml/27a8306a-23dc-4523-a7a5-ff46f74d4957/wd/inferences_workspaceblobstore'.
# [2022-02-09T16:01:33.767] Mounting inferences to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlresource-aml/azureml/27a8306a-23dc-4523-a7a5-ff46f74d4957/wd/inferences_workspaceblobstore
# [2022-02-09T16:01:33.767] Output is not a single file
# [2022-02-09T16:01:33.767] Mounted inferences to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlresource-aml/azureml/27a8306a-23dc-4523-a7a5-ff46f74d4957/wd/inferences_workspaceblobstore as folder
# [2022-02-09T16:01:34.461] Mounting diabetes_batch to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlresource-aml/azureml/27a8306a-23dc-4523-a7a5-ff46f74d4957/wd/diabetes_batch_be4d3d64-64dd-4372-ac8b-35c2523cb4c6.
# [2022-02-09T16:01:35.466] Mounting inferences to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlresource-aml/azureml/27a8306a-23dc-4523-a7a5-ff46f74d4957/wd/inferences_workspaceblobstore.
# [2022-02-09T16:01:35.469] Mounted diabetes_batch to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlresource-aml/azureml/27a8306a-23dc-4523-a7a5-ff46f74d4957/wd/diabetes_batch_be4d3d64-64dd-4372-ac8b-35c2523cb4c6.
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (azure-core 1.21.1 (/opt/miniconda/lib/python3.7/site-packages), Requirement.parse('azure-core<1.21')).
# [2022-02-09T16:01:40.544] Mounted inferences to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlresource-aml/azureml/27a8306a-23dc-4523-a7a5-ff46f74d4957/wd/inferences_workspaceblobstore.
# [2022-02-09T16:01:40.575] Exit __enter__ of DatasetContextManager
# uri entered in sidecar: None
# Set Dataset diabetes_batch's target path to /mnt/batch/tasks/shared/LS_root/jobs/mlresource-aml/azureml/27a8306a-23dc-4523-a7a5-ff46f74d4957/wd/diabetes_batch_be4d3d64-64dd-4372-ac8b-35c2523cb4c6
# Set OutputDataset inferences's target path to /mnt/batch/tasks/shared/LS_root/jobs/mlresource-aml/azureml/27a8306a-23dc-4523-a7a5-ff46f74d4957/wd/inferences_workspaceblobstore
# [2022-02-09T16:01:40.576497] INFO azureml.sidecar.task.enter_contexts: Entered Context Managers
# [2022-02-09T16:01:40.974744] Ran Sidecar prep cmd.
# [2022-02-09T16:01:40.975134] Running Context Managers in Sidecar complete.
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2022/02/09 16:02:28 Didn't get JobInfoJson from env, now read from file
# 2022/02/09 16:02:28 Suceeded read JobInfoJson from file
# 2022/02/09 16:02:28 Starting App Insight Logger for task:  runTaskLet
# 2022/02/09 16:02:28 Version: 3.0.01853.0004 Branch: .SourceBranch Commit: df26c27
# 2022/02/09 16:02:28 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/info
# 2022/02/09 16:02:28 Send process info logs to master server succeeded
# 2022/02/09 16:02:28 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/status
# 2022/02/09 16:02:28 Send process info logs to master server succeeded
# [2022-02-09T16:02:28.716819] Entering context manager injector.
# [2022-02-09T16:02:29.325248] context_manager_injector.py Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'Dataset:context_managers.Datasets', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['driver/amlbi_main.py', '--client_sdk_version', '1.37.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', 'DatasetOutputConfig:inferences', '--input_fds_0', 'diabetes_batch'])
# Script type = None
# [2022-02-09T16:02:29.329574] Entering Run History Context Manager.
# [2022-02-09T16:02:30.119908] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/mlresource-aml/azureml/27a8306a-23dc-4523-a7a5-ff46f74d4957/wd/azureml/27a8306a-23dc-4523-a7a5-ff46f74d4957
# [2022-02-09T16:02:30.119955] Preparing to call script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.37.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '$inferences', '--input_fds_0', 'diabetes_batch']
# [2022-02-09T16:02:30.119978] After variable expansion, calling script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.37.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/mlresource-aml/azureml/27a8306a-23dc-4523-a7a5-ff46f74d4957/wd/inferences_workspaceblobstore', '--input_fds_0', 'diabetes_batch']
#
# 2022/02/09 16:02:33 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
#
#
# [2022-02-09T16:03:11.571913] The experiment failed. Finalizing run...
#
# Streaming azureml-logs/75_job_post-tvmps_25449a4c9f14b465a4eb4efea0ed998d7c9c94ae8bd3149f0936d8a3261c9bcd_d.txt
# ===============================================================================================================
# [2022-02-09T16:03:16.460720] Entering job release
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (azure-core 1.21.1 (/opt/miniconda/lib/python3.7/site-packages), Requirement.parse('azure-core<1.21')).
# [2022-02-09T16:03:17.259814] job release stage : copy_batchai_cached_logs starting...
# [2022-02-09T16:03:17.259859] job release stage : copy_batchai_cached_logs completed...
# [2022-02-09T16:03:17.259988] Running in AzureML-Sidecar, starting to exit user context managers...
# [2022-02-09T16:03:17.260584] Running Sidecar release cmd...
# [2022-02-09T16:03:17.270568] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlresource-aml/azureml/27a8306a-23dc-4523-a7a5-ff46f74d4957/wd/azureml/27a8306a-23dc-4523-a7a5-ff46f74d4957
# [2022-02-09T16:03:17.285] Enter __exit__ of DatasetContextManager
# [2022-02-09T16:03:17.285] Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlresource-aml/azureml/27a8306a-23dc-4523-a7a5-ff46f74d4957/wd/diabetes_batch_be4d3d64-64dd-4372-ac8b-35c2523cb4c6.
# [2022-02-09T16:03:18.301] Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlresource-aml/azureml/27a8306a-23dc-4523-a7a5-ff46f74d4957/wd/diabetes_batch_be4d3d64-64dd-4372-ac8b-35c2523cb4c6.
# [2022-02-09T16:03:18.301] Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlresource-aml/azureml/27a8306a-23dc-4523-a7a5-ff46f74d4957/wd/inferences_workspaceblobstore.
# [2022-02-09T16:03:18.331] Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlresource-aml/azureml/27a8306a-23dc-4523-a7a5-ff46f74d4957/wd/inferences_workspaceblobstore.
# [2022-02-09T16:03:18.331] Exit __exit__ of DatasetContextManager
# [2022-02-09T16:03:18.331201] Removing absolute paths from host...
# [2022-02-09T16:03:18.331522] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2022-02-09T16:03:18.559649] Ran Sidecar release cmd.
#
# StepRun(batch-score-diabetes) Execution Summary
# ================================================
# StepRun( batch-score-diabetes ) Status: Failed
#
# Warnings:
# {
#   "error": {
#     "code": "UserError",
#     "severity": null,
#     "message": "AzureMLCompute job failed.\nJobFailed: Submitted script failed with a non-zero exit code; see the driver log file for details.\n\tReason: Job failed with non-zero exit Code",
#     "messageFormat": "{Message}",
#     "messageParameters": {
#       "Message": "AzureMLCompute job failed.\nJobFailed: Submitted script failed with a non-zero exit code; see the driver log file for details.\n\tReason: Job failed with non-zero exit Code"
#     },
#     "referenceCode": null,
#     "detailsUri": null,
#     "target": null,
#     "details": [],
#     "innerError": {
#       "code": "UserTrainingScriptFailed",
#       "innerError": null
#     },
#     "debugInfo": null,
#     "additionalInfo": null
#   },
#   "correlation": {
#     "operation": "481c98ab99c8414ca0d1ea2cb55ac8c6",
#     "request": "d1b42035c0891ea4"
#   },
#   "environment": "eastus",
#   "location": "eastus",
#   "time": "2022-02-09T16:03:32.7300781+00:00",
#   "componentName": "globaljobdispatcher"
# }
# ---------------------------------------------------------------------------
# ActivityFailedException                   Traceback (most recent call last)
# <ipython-input-10-3f971d0c5b0f> in <module>
#       4 pipeline = Pipeline(workspace=ws, steps=[parallelrun_step])
#       5 pipeline_run = Experiment(ws, 'mslearn-diabetes-batch').submit(pipeline)
# ----> 6 pipeline_run.wait_for_completion(show_output=True)
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/pipeline/core/run.py in wait_for_completion(self, show_output, timeout_seconds, raise_on_error)
#     294                             try:
#     295                                 step_run.wait_for_completion(timeout_seconds=timeout_seconds - time_elapsed,
# --> 296                                                              raise_on_error=raise_on_error)
#     297                             except TypeError as e:
#     298                                 # If there are package conflicts in the user's environment, the run rehydration
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/pipeline/core/run.py in wait_for_completion(self, show_output, timeout_seconds, raise_on_error)
#     736             try:
#     737                 return self._stream_run_output(timeout_seconds=timeout_seconds,
# --> 738                                                raise_on_error=raise_on_error)
#     739             except KeyboardInterrupt:
#     740                 error_message = "The output streaming for the run interrupted.\n" \
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/pipeline/core/run.py in _stream_run_output(self, timeout_seconds, raise_on_error)
#     828             print(json.dumps(error, indent=4))
#     829         if error and raise_on_error:
# --> 830             raise ActivityFailedException(error_details=json.dumps(error, indent=4))
#     831
#     832         print(final_details)
#
# ActivityFailedException: ActivityFailedException:
# 	Message: Activity Failed:
# {
#     "error": {
#         "code": "UserError",
#         "message": "User program failed with Exception: Run failed, please check logs for details. You can check logs/readme.txt for the layout of logs.",
#         "messageParameters": {},
#         "detailsUri": "https://aka.ms/azureml-run-troubleshooting",
#         "details": []
#     },
#     "time": "0001-01-01T00:00:00.000Z"
# }
# 	InnerException None
# 	ErrorResponse
# {
#     "error": {
#         "message": "Activity Failed:\n{\n    \"error\": {\n        \"code\": \"UserError\",\n        \"message\": \"User program failed with Exception: Run failed, please check logs for details. You can check logs/readme.txt for the layout of logs.\",\n        \"messageParameters\": {},\n        \"detailsUri\": \"https://aka.ms/azureml-run-troubleshooting\",\n        \"details\": []\n    },\n    \"time\": \"0001-01-01T00:00:00.000Z\"\n}"
#     }
# }

# %% [markdown]
# When the pipeline has finished running, the resulting predictions will have been saved in the outputs of the experiment associated with the first (and only) step in the pipeline. You can retrieve it as follows:

# %%
import pandas as pd
import shutil

# Remove the local results folder if left over from a previous run
shutil.rmtree('diabetes-results', ignore_errors=True)

# Get the run for the first step and download its output
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')

# Traverse the folder hierarchy and find the results file
for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-8abc90127c6c> in <module>
#       7 # Get the run for the first step and download its output
#       8 prediction_run = next(pipeline_run.get_children())
# ----> 9 prediction_output = prediction_run.get_output_data('inferences')
#      10 prediction_output.download(local_path='diabetes-results')
#      11
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/pipeline/core/run.py in get_output_data(self, name)
#     712         :rtype: azureml.pipeline.core.PortDataReference
#     713         """
# --> 714         return self.get_output(name).get_port_data_reference()
#     715
#     716     def wait_for_completion(self, show_output=True, timeout_seconds=sys.maxsize, raise_on_error=True):
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/pipeline/core/run.py in get_output(self, name)
#     700         :rtype: azureml.pipeline.core.StepRunOutput
#     701         """
# --> 702         return self._step_run_provider.get_output(self, self._context, self._pipeline_run_id, self._node_id, name)
#     703
#     704     def get_output_data(self, name):
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/pipeline/core/_aeva_provider.py in get_output(self, step_run, context, pipeline_run_id, node_id, name)
#    1318         """
#    1319         node_outputs = self._service_caller.get_node_outputs_async(pipeline_run_id, node_id)
# -> 1320         return StepRunOutput(context, pipeline_run_id, step_run, name, node_outputs[name])
#    1321
#    1322
#
# KeyError: 'inferences'

# %% [markdown]
# ## Publish the Pipeline and use its REST Interface
#
# Now that you have a working pipeline for batch inferencing, you can publish it and use a REST endpoint to run it from an application.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name='diabetes-batch-pipeline', description='Batch scoring of diabetes data', version='1.0')

published_pipeline

# %% [markdown]
# Note that the published pipeline has an endpoint, which you can see in the Azure portal. You can also find it as a property of the published pipeline object:

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)

# %% [markdown]
# To use the endpoint, client applications need to make a REST call over HTTP. This request must be authenticated, so an authorization header is required. To test this out, we'll use the authorization header from your current connection to your Azure workspace, which you can get using the following code:
#
# > **Note**: A real application would require a service principal with which to be authenticated.

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()
print('Authentication header ready.')

# %% [markdown]
# Now we're ready to call the REST interface. The pipeline runs asynchronously, so we'll get an identifier back, which we can use to track the pipeline experiment as it runs:

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "mslearn-diabetes-batch"})
run_id = response.json()["Id"]
run_id

# %% [markdown]
# Since we have the run ID, we can use the **RunDetails** widget to view the experiment as it runs:

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments['mslearn-diabetes-batch'], run_id)

# Block until the run completes
published_pipeline_run.wait_for_completion(show_output=True)

# %% [markdown]
# Wait for the pipeline run to complete, and then run the following cell to see the results.
#
# As before, the results are in the output of the first pipeline step:

# %%
import pandas as pd
import shutil

# Remove the local results folder if left over from a previous run
shutil.rmtree('diabetes-results', ignore_errors=True)

# Get the run for the first step and download its output
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')

# Traverse the folder hierarchy and find the results file
for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)

# %% [markdown]
# Now you have a pipeline that can be used to batch process daily patient data.
#
# **More Information**: For more details about using pipelines for batch inferencing, see the [How to Run Batch Predictions](https://docs.microsoft.com/azure/machine-learning/how-to-run-batch-predictions) in the Azure Machine Learning documentation.
